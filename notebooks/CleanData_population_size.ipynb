# %%
import pandas as pd
import matplotlib.pyplot as plt
import functions 
import pandas as pd
from shapely.geometry import Point
from shapely import wkt
import geopandas as gpd
# load data
raw_populationsize = pd.read_csv("../data/raw/populationsize_zh.csv")
#clean and filter data
#choose year 2025
pop_size= raw_populationsize[raw_populationsize["StichtagDatJahr"]	== 2025]
#select useful columns
# Out:
#      StichtagDatJahr  QuarSort     QuarLang  AnzBestWir
# 0               2025        11      Rathaus        3252
# 85              2025        12  Hochschulen         688
# 170             2025        13    Lindenhof        1038
